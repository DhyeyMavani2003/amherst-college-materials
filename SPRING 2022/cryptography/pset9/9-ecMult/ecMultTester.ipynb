# %% [markdown]
# Write a function $\texttt{ecMult(n,P,A,B,p)}$ that computes an integer multiple $n \cdot P$ of a point $P$ on an elliptic curve $Y^2 \equiv X^3 + A X + B \pmod{p}$. Points will be formatted $(x,y)$, with $0 \leq x,y < p$, while the point at infinity should be denoted simply as $0$

# %%
# Run this cell every time you change your source code.
import importlib, ecMultSoln
importlib.reload(ecMultSoln)
from ecMultSoln import ecMult

# %%
# Sample test case (4-bit modulus)
# Expected: (0, 8)
# Time limit: 1s (not enforced by this notebook)
ecMult(7,(0, 5),7,12,13)
# Out:
# (0, 8)

# %%
# Sample test case (64-bit modulus)
# Expected: (12759430319363092786, 803774938576190289)
# Time limit: 1s (not enforced by this notebook)
ecMult(8047589620005923936,(4297526872213605913, 4419661898306486976),6769479232518810790,12758838330961928686,17019504244839748279)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/rb/x4vhwjb16wj764ztdb96gnlh0000gn/T/ipykernel_25836/3331195139.py in <module>
#       2 # Expected: (12759430319363092786, 803774938576190289)
#       3 # Time limit: 1s (not enforced by this notebook)
# ----> 4 ecMult(8047589620005923936,(4297526872213605913, 4419661898306486976),6769479232518810790,12758838330961928686,17019504244839748279)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#      12     else:
#      13         new_rec = ecAdd(rec,P,A,B,p)
# ---> 14         return ecAdd(rec,new_rec,A,B,p)
#      15
#      16
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecAdd(P, Q, A, B, p)
#      44     if (xp == xq):
#      45         return 0
# ---> 46     m = (yq - yp)*modinv((xq - xp),p)%p
#      47     h = (yp - m*xp)%p
#      48     x = (m**2 - xp - xq)%p
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'

# %%
# Sample test case (5-bit modulus)
# Expected: 0
# Time limit: 1s (not enforced by this notebook)
ecMult(0,(2, 13),2,4,17)
# Out:
# 0

# %%
# Sample test case (5-bit modulus)
# Expected: 0
# Time limit: 1s (not enforced by this notebook)
ecMult(8,(0, 25),26,16,29)
# Out:
# (0, 25)
# (16, 27)
# (10, 0)
# 0

# %%
# Sample test case (16-bit modulus)
# Expected: (51674, 9008)
# Time limit: 1s (not enforced by this notebook)
ecMult(59238,(30098, 53206),25273,34491,58153)
# Out:
# 0
# (30098, 53206)
# (29226, 17363)
# (16282, 39317)
# (5565, 3736)
# (14445, 48719)
# (42525, 39632)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/rb/x4vhwjb16wj764ztdb96gnlh0000gn/T/ipykernel_25836/3461682674.py in <module>
#       2 # Expected: (51674, 9008)
#       3 # Time limit: 1s (not enforced by this notebook)
# ----> 4 ecMult(59238,(30098, 53206),25273,34491,58153)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ...
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n/2,P,A,B,p)
#       9     print(rec)
#      10     if n%2 == 0:
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#      11         return ecAdd(rec,rec,A,B,p)
#      12     else:
# ---> 13         new_rec = ecAdd(rec,P,A,B,p)
#      14         return ecAdd(rec,new_rec,A,B,p)
#      15
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecAdd(P, Q, A, B, p)
#      42         return (x,y)
#      43
# ---> 44     m = (yq - yp)*modinv((xq - xp),p)%p
#      45     h = (yp - m*xp)%p
#      46     x = (m**2 - xp - xq)%p
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'

# %%
# Sample test case (64-bit modulus)
# Expected: (13744576389446995533, 8713767026666143740)
# Time limit: 1s (not enforced by this notebook)
ecMult(9668710614673218952,(5510720254742439893, 6576665640390421175),16570263188189913526,16488692511132208413,16967927074872114437)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/rb/x4vhwjb16wj764ztdb96gnlh0000gn/T/ipykernel_25836/3615221206.py in <module>
#       2 # Expected: (13744576389446995533, 8713767026666143740)
#       3 # Time limit: 1s (not enforced by this notebook)
# ----> 4 ecMult(9668710614673218952,(5510720254742439893, 6576665640390421175),16570263188189913526,16488692511132208413,16967927074872114437)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#       6         return P
#       7
# ----> 8     rec = ecMult(n//2,P,A,B,p)
#       9     if n%2 == 0:
#      10         return ecAdd(rec,rec,A,B,p)
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecMult(n, P, A, B, p)
#      10         return ecAdd(rec,rec,A,B,p)
#      11     else:
# ---> 12         new_rec = ecAdd(rec,P,A,B,p)
#      13         return ecAdd(rec,new_rec,A,B,p)
#      14
#
# ~/Desktop/SPRING 2022/cryptography/pset9/9-ecMult/ecMultSoln.py in ecAdd(P, Q, A, B, p)
#      41         return (x,y)
#      42
# ---> 43     m = (yq - yp)*modinv((xq - xp),p)%p
#      44     h = (yp - m*xp)%p
#      45     x = (m**2 - xp - xq)%p
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'
